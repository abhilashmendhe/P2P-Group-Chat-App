# %%
# %load_ext autoreload
# %autoreload 2

# %%
from generate_data_helper import *
from read_and_clean_helper import *
from plot_fns_helper3 import *
import random

# %%
push_path = "../mesh-arch-testing/push"
pull_path = "../mesh-arch-testing/pull3"

# %%
df_mesh_push1 = read_from_ks("k1", push_path)
df_mesh_push2 = read_from_ks("k2", push_path)
df_mesh_push3 = read_from_ks("k3", push_path)
df_mesh_push4 = read_from_ks("k4", push_path)
# p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df1)
# p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df2)
# p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df3)
# p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df4)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_push1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_push2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_push3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_push4)

# %%
print("CRDT Insights for Push (Gossip NO GC) Mesh (11 nodes), 3 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 92,",f"t_last : {(all_timestamps1[92] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 91,",f"t_last : {(all_timestamps2[91] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 89,",f"t_last : {(all_timestamps3[89] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 88,",f"t_last : {(all_timestamps4[88] - all_timestamps4[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1}") 
print(f"\ttotal object transfer: {totalobjs1} total delta object transfer: {total_delta_objs1}\n")
print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2}") 
print(f"\ttotal object transfer: {totalobjs2}, total delta object transfer: {total_delta_objs2}\n")
print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3}") 
print(f"\ttotal object transfer: {totalobjs3}, total delta object transfer: {total_delta_objs3}\n")
print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4}") 
print(f"\ttotal object transfer: {totalobjs4}, total delta object transfer: {total_delta_objs4}\n")
# Out:
# CRDT Insights for Push (Gossip NO GC) Mesh (11 nodes), 3 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 92, t_last : 460.0
# 	k2 -- converge at round: 91, t_last : 455.0
# 	k3 -- converge at round: 89, t_last : 445.0
# 	k4 -- converge at round: 88, t_last : 440.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 10.818181818181817, total data transfer: 20167846.0
# 	total object transfer: 116837.0 total delta object transfer: 100535.0
#
# 	k2 -- traffic count: 18.462809917355376, total data transfer: 22946793.0
# 	total object transfer: 133277.0, total delta object transfer: 108898.564244655
#
# 	k3 -- traffic count: 23.88429752066116, total data transfer: 26085521.0
# 	total object transfer: 149363.0, total delta object transfer: 118814.375882461
#
# 	k4 -- traffic count: 27.553719008264466, total data transfer: 26897722.0
# ...

# %%
print(traffic_count_1, traffic_count_2, traffic_count_3, traffic_count_4)
print(total_data_transfer1, total_data_transfer2, total_data_transfer3, total_data_transfer4)
print(totalobjs1, totalobjs2, totalobjs3, totalobjs4)
print(total_delta_objs1, total_delta_objs2, total_delta_objs3, total_delta_objs4)
# Out:
# 10.818181818181817 18.462809917355376 23.88429752066116 27.553719008264466
# 20167846.0 22946793.0 26085521.0 26897722.0
# 116837.0 133277.0 149363.0 155289.0
# 100535.0 108898.564244655 118814.375882461 122062.490134379

# %%
# # plot_function(p12_data, p22_data, p32_data, p42_data, "push","concurrent")
# plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, "Push", "concurr", "Residue")
# plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, "Push", "concurr", "Cummulative Residue")

# %%
# plot_cdf(p12_data, p22_data, p32_data, p42_data, "Push", "concurrent")

# %%
df_mesh_pull1 = read_from_ks("k1", pull_path)
df_mesh_pull2 = read_from_ks("k2", pull_path)
df_mesh_pull3 = read_from_ks("k3", pull_path)
df_mesh_pull4 = read_from_ks("k4", pull_path)
# # p11_data, p12_data, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1 = get_p1_p2_data(df1)
# # p21_data, p22_data, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2 = get_p1_p2_data(df2)
# # p31_data, p32_data, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3 = get_p1_p2_data(df3)
# # p41_data, p42_data, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4 = get_p1_p2_data(df4)
# p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df1)
# p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df2)
# p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df3)
# p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df4)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_pull1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_pull2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_pull3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_pull4)

# %%
print("CRDT Insights for Pull (Anti-Entropy NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 92,",f"t_last : {(all_timestamps1[92] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 94,",f"t_last : {(all_timestamps2[94] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 93,",f"t_last : {(all_timestamps3[93] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 54,",f"t_last : {(all_timestamps4[54] - all_timestamps4[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1}") 
print(f"\ttotal object transfer: {totalobjs1} total delta object transfer: {total_delta_objs1}\n")
print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2}") 
print(f"\ttotal object transfer: {totalobjs2}, total delta object transfer: {total_delta_objs2}\n")
print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3}") 
print(f"\ttotal object transfer: {totalobjs3}, total delta object transfer: {total_delta_objs3}\n")
print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4}") 
print(f"\ttotal object transfer: {totalobjs4}, total delta object transfer: {total_delta_objs4}\n")
# Out:
# CRDT Insights for Pull (Anti-Entropy NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 92, t_last : 460.0
# 	k2 -- converge at round: 94, t_last : 470.0
# 	k3 -- converge at round: 93, t_last : 465.0
# 	k4 -- converge at round: 54, t_last : 270.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 34.52892561983471, total data transfer: 9571615.0
# 	total object transfer: 67213 total delta object transfer: 37050
#
# 	k2 -- traffic count: 55.43801652892562, total data transfer: 14603849.0
# 	total object transfer: 107585, total delta object transfer: 53288
#
# 	k3 -- traffic count: 58.66115702479339, total data transfer: 15033745.0
# 	total object transfer: 109060, total delta object transfer: 53412
#
# 	k4 -- traffic count: 66.6198347107438, total data transfer: 14540867.0
# ...

# %%
print(traffic_count_1, traffic_count_2, traffic_count_3, traffic_count_4)
print(total_data_transfer1, total_data_transfer2, total_data_transfer3, total_data_transfer4)
print(totalobjs1, totalobjs2, totalobjs3, totalobjs4)
print(total_delta_objs1, total_delta_objs2, total_delta_objs3, total_delta_objs4)
# Out:
# 34.52892561983471 55.43801652892562 58.66115702479339 66.6198347107438
# 9571615.0 14603849.0 15033745.0 14540867.0
# 67213 107585 109060 121061
# 37050 53288 53412 56239

# %%
plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, "Pull", "concurr", "Residue")
plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, "Pull", "concurr", "Cummulative Residue")
# Out:
# [np.float64(0.0), np.float64(20.0), np.float64(40.0), np.float64(60.0), 65, 77, np.float64(80.0), 81, 81, np.float64(100.0), np.float64(120.0), np.float64(140.0)]

# %%
plot_cdf(p12_data, p22_data, p32_data, p42_data, "Pull", "concurrent")
