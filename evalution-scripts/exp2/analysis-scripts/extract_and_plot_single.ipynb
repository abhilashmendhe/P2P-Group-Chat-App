# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from generate_data_helper import *
from read_and_clean_helper import *
from plot_fns_helper import *
from plot_fns_helper import plot_function, plot_cdf

# %%
push_path = "./mesh/push"
pull_path = "./mesh/pull"

push_tree_path = "./tree/push"
pull_tree_path = "./tree/pull"

# %%
df1 = read_from_ks("k1", pull_path)
df2 = read_from_ks("k2", pull_path)
df3 = read_from_ks("k3", pull_path)
df4 = read_from_ks("k4", pull_path)
p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df1)
p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df2)
p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df3)
p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df4)

# %%
df_tree_pull = read_from_tree(pull_tree_path)
tree_pull_data1, tree_pull_data2, tree_pull_all_timestamps1, tree_pull_traffic_count_1, tree_pull_total_data_transfer1, tree_pull_totalobjs1, tree_pull_total_delta_objs1, tree_pull_mean_merge1, tree_pull_c_ind1, tree_pull_c_value1 = get_p1_p2_data(df_tree_pull)

# %%
c_ind1, c_ind2, c_ind3, c_ind4
# Out:
# (92, 95, 93, 54)

# %%
traffic_count_1,traffic_count_2,traffic_count_3,traffic_count_4
# Out:
# (40.3801652892562, 64.57851239669422, 76.25619834710746, 60.95867768595042)

# %%
# total_data_transfer1, total_data_transfer2, total_data_transfer3, total_data_transfer4
print("pull (anti-entropy), Total Data Transfer (bytes), Total git objects Transfer, Total Delta Git objects Transfer, Total Traffic")
print("    k=1,                               342145.0,                       3277,                              224,  24.669421487603305")
print("    k=2,                              8776800.0,                      70820,                            15295,  68.56198347107438")
print("    k=3,                             10280725.0,                      83972,                            17967,  83.01652892561985")
print("    k=4,                             13344005.0,                     100973,                            23108, 112.669421487603305")
# Out:
# pull (anti-entropy), Total Data Transfer (bytes), Total git objects Transfer, Total Delta Git objects Transfer, Total Traffic
#     k=1,                               342145.0,                       3277,                              224,  24.669421487603305
#     k=2,                              8776800.0,                      70820,                            15295,  68.56198347107438
#     k=3,                             10280725.0,                      83972,                            17967,  83.01652892561985
#     k=4,                             13344005.0,                     100973,                            23108, 112.669421487603305

# %%
print(traffic_count_1, traffic_count_2, traffic_count_3, traffic_count_4)
print(total_data_transfer1, total_data_transfer2, total_data_transfer3, total_data_transfer4)
print(totalobjs1, totalobjs2, totalobjs3, totalobjs4)
print(total_delta_objs1, total_delta_objs2, total_delta_objs3, total_delta_objs4)
# Out:
# 40.3801652892562 64.57851239669422 76.25619834710746 60.95867768595042
# 5916550.0 8083330.0 7949188.0 7137597.0
# 41870 64079 71370 51272
# 9003 12638 11027 14370

# %%
plot_function(p12_data, p22_data, p32_data, p42_data, tree_pull_data2,"pull","single")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_function(p12_data, p22_data, p32_data, p42_data, tree_pull_data2,"pull","single")
#
# NameError: name 'plot_function' is not defined

# %%
plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "pull (anti-entropy)", "single")

# %%
df1 = read_from_ks("k1", push_path)
df2 = read_from_ks("k2", push_path)
# for obj in df2['total_objs']:
#     print(obj)
df3 = read_from_ks("k3", push_path)
df4 = read_from_ks("k4", push_path)
p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df1)
p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df2)
p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df3)
p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df4)

# %%
print("push (gossip),      Total Data Transfer (bytes), Total git objects Transfer, Total Delta Git objects Transfer, Total Traffic")
print("    k=1,                            10597137.0,                      59675,                            46298,  10.388429752066116")
print("    k=2,                            13601392.0,                      75575,                            55433,  17.02479338842975")
print("    k=3,                            14908225.0,                      82730,                            59088,  22.59504132231405")
print("    k=4,                            16558928.0,                      92613,                            65734,  26.074380165289256")
# Out:
# push (gossip),      Total Data Transfer (bytes), Total git objects Transfer, Total Delta Git objects Transfer, Total Traffic
#     k=1,                            10597137.0,                      59675,                            46298,  10.388429752066116
#     k=2,                            13601392.0,                      75575,                            55433,  17.02479338842975
#     k=3,                            14908225.0,                      82730,                            59088,  22.59504132231405
#     k=4,                            16558928.0,                      92613,                            65734,  26.074380165289256

# %%
total_data_transfer1, total_data_transfer2, total_data_transfer3, total_data_transfer4
# Out:
# (np.float64(10597137.0),
#  np.float64(13601392.0),
#  np.float64(14908225.0),
#  np.float64(16558928.0))

# %%
totalobjs1, totalobjs2, totalobjs3, totalobjs4
# Out:
# (np.float64(59675.0),
#  np.float64(75575.0),
#  np.float64(82730.0),
#  np.float64(92613.0))

# %%
total_delta_objs1, total_delta_objs2,total_delta_objs3,total_delta_objs4
# Out:
# (np.float64(46298.0),
#  np.float64(55433.376392862),
#  np.float64(59088.210028392),
#  np.float64(65734.234057162))

# %%
df_tree_push = read_from_tree(push_tree_path)
tree_push_data1, tree_push_data2, tree_push_all_timestamps1, tree_push_traffic_count_1, tree_push_total_data_transfer1, tree_push_totalobjs1, tree_push_total_delta_objs1, tree_push_mean_merge1, tree_push_c_ind1, tree_push_c_value1 = get_p1_p2_data(df_tree_push)

# %%
plot_function(p11_data, p21_data, p31_data, p41_data, tree_push_data1, "push","single")

# %%
plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_push_data2, "push (gossip)", "single")
