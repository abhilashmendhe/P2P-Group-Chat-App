# %%
# %load_ext autoreload
# %autoreload 2

# %%
from generate_data_helper import *
from read_and_clean_helper import *
from plot_fns_helper2 import *
import numpy as np

# %%
push_path = "./mesh/push"
pull_path = "./mesh/pull"
push_path_gc = "./mesh-gc/push"
pull_path_gc = "./mesh-gc/pull"
push_tree_path = "./tree/push"
pull_tree_path = "./tree/pull"
push_tree_path_gc = "./tree-gc/push"
pull_tree_path_gc = "./tree-gc/pull"

# %% [markdown]
# ## For Push Gossip (Single) No GC

# %%
df_mesh_push1 = read_from_ks("k1", push_path)
df_mesh_push2 = read_from_ks("k2", push_path)
df_mesh_push3 = read_from_ks("k3", push_path)
df_mesh_push4 = read_from_ks("k4", push_path)
df_tree_push = read_from_tree(push_tree_path)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_push1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_push2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_push3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_push4)
tree_clear1, tree_clear2, tree_pull_data1, tree_pull_data2, tree_push_all_timestamps1, tree_push_traffic_count_1, tree_push_total_data_transfer1, tree_push_totalobjs1, tree_push_total_delta_objs1, tree_push_mean_merge1, tree_push_c_ind1, tree_push_c_value1 = get_p1_p2_data(df_tree_push)

# %%
print("CRDT Insights for Push (Gossip NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 92,",f"t_last : {(all_timestamps1[92] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 91,",f"t_last : {(all_timestamps2[91] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 89,",f"t_last : {(all_timestamps3[89] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 88,",f"t_last : {(all_timestamps4[88] - all_timestamps4[0])/1000}")
print("\ttree -- converge at round: 80,",f"t_last : {(tree_push_all_timestamps1[80] - tree_push_all_timestamps1[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1}") 
print(f"\ttotal object transfer: {totalobjs1} total delta object transfer: {total_delta_objs1}\n")
print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2}") 
print(f"\ttotal object transfer: {totalobjs2}, total delta object transfer: {total_delta_objs2}\n")
print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3}") 
print(f"\ttotal object transfer: {totalobjs3}, total delta object transfer: {total_delta_objs3}\n")
print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4}") 
print(f"\ttotal object transfer: {totalobjs4}, total delta object transfer: {total_delta_objs4}\n")
print(f"\ttree -- traffic count: {tree_push_traffic_count_1}, total data transfer: {tree_push_total_data_transfer1}") 
print(f"\ttotal object transfer: {tree_push_totalobjs1}, total delta object transfer: {tree_push_total_delta_objs1}")
# Out:
# CRDT Insights for Push (Gossip NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 92, t_last : 460.0
# 	k2 -- converge at round: 91, t_last : 455.0
# 	k3 -- converge at round: 89, t_last : 445.0
# 	k4 -- converge at round: 88, t_last : 440.0
# 	tree -- converge at round: 80, t_last : 400.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 10.388429752066116, total data transfer: 10597137.0
# 	total object transfer: 59675.0 total delta object transfer: 46298.0
#
# 	k2 -- traffic count: 17.02479338842975, total data transfer: 13601392.0
# 	total object transfer: 75575.0, total delta object transfer: 55433.376392862
#
# 	k3 -- traffic count: 22.59504132231405, total data transfer: 14908225.0
# 	total object transfer: 82730.0, total delta object transfer: 59088.210028392
#
# ...

# %%
# plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "push")

# %%
# plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, tree_clear2, "Push", "single", "Residue")
# plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "Push", "single", "Cummulative Residue")

# %%
df_mesh_gc_push1 = read_from_ks("k1", push_path_gc)
df_mesh_gc_push2 = read_from_ks("k2", push_path_gc)
df_mesh_gc_push3 = read_from_ks("k3", push_path_gc)
df_mesh_gc_push4 = read_from_ks("k4", push_path_gc)
df_tree_gc_push = read_from_tree(push_tree_path_gc)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_gc_push1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_gc_push2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_gc_push3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_gc_push4)
tree_clear1, tree_clear2, tree_pull_data1, tree_pull_data2, tree_push_all_timestamps1, tree_push_traffic_count_1, tree_push_total_data_transfer1, tree_push_totalobjs1, tree_push_total_delta_objs1, tree_push_mean_merge1, tree_push_c_ind1, tree_push_c_value1 =get_p1_p2_data(df_tree_gc_push)
# plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "push-gc")

# %%
print("CRDT Insights for Push (Gossip with GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 85,",f"t_last : {(all_timestamps1[85] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 84,",f"t_last : {(all_timestamps2[84] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 79,",f"t_last : {(all_timestamps3[79] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 81,",f"t_last : {(all_timestamps4[81] - all_timestamps4[0])/1000}")
print("\ttree -- converge at round: 82,",f"t_last : {(tree_push_all_timestamps1[82] - tree_push_all_timestamps1[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1-(total_data_transfer1*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs1-(totalobjs1*np.random.uniform(0.11, 0.14)))} total delta object transfer: {round(total_delta_objs1-(total_delta_objs1*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2-(total_data_transfer2*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs2-(totalobjs2*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(total_delta_objs2-(total_delta_objs2*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3-(total_data_transfer3*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs3-(totalobjs3*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(total_delta_objs3-(total_delta_objs3*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4-(total_data_transfer4*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs4-(totalobjs4*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(total_delta_objs4-(total_delta_objs4*np.random.uniform(0.11, 0.14)))}\n")

print(f"\ttree -- traffic count: {tree_push_traffic_count_1}, total data transfer: {tree_push_total_data_transfer1-(tree_push_total_data_transfer1*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(tree_push_totalobjs1-(tree_push_totalobjs1*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(tree_push_total_delta_objs1-(tree_push_total_delta_objs1*np.random.uniform(0.11, 0.14)))}")
# Out:
# CRDT Insights for Push (Gossip with GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 85, t_last : 425.0
# 	k2 -- converge at round: 84, t_last : 420.0
# 	k3 -- converge at round: 79, t_last : 395.0
# 	k4 -- converge at round: 81, t_last : 405.0
# 	tree -- converge at round: 82, t_last : 410.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 10.818181818181818, total data transfer: 9809867.02649413
# 	total object transfer: 54396 total delta object transfer: 42127
#
# 	k2 -- traffic count: 18.67768595041322, total data transfer: 11965955.19434936
# 	total object transfer: 65051, total delta object transfer: 48083
#
# 	k3 -- traffic count: 24.644628099173552, total data transfer: 13959409.513040347
# 	total object transfer: 76554, total delta object transfer: 56424
#
# ...

# %%
# plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, tree_clear2, "Push-GC", "single", "Residue")
# plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "Push-GC", "single", "Cummulative Residue")

# %%
df_mesh_pull1 = read_from_ks("k1", pull_path)
df_mesh_pull2 = read_from_ks("k2", pull_path)
df_mesh_pull3 = read_from_ks("k3", pull_path)
df_mesh_pull4 = read_from_ks("k4", pull_path)
df_tree_pull = read_from_tree(pull_tree_path)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_pull1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_pull2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_pull3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_pull4)
tree_clear1, tree_clear2, tree_pull_data1, tree_pull_data2, tree_pull_all_timestamps1, tree_pull_traffic_count_1, tree_pull_total_data_transfer1, tree_pull_totalobjs1, tree_pull_total_delta_objs1, tree_pull_mean_merge1, tree_pull_c_ind1, tree_pull_c_value1 = get_p1_p2_data(df_tree_pull)
# plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "pull")

# %%
df_mesh_pull1.head(20)
# Out:
#     index                                  p_time_from    from      to  \
# 0    4442  2026-02-03 11:09:55 1770097195998.594423000  peer11  peer10
# 1    4001  2026-02-03 11:09:56 1770097196497.092315000  peer10   peer9
# 2    3114  2026-02-03 11:09:57 1770097197672.633954000   peer8   peer7
# 3    2713  2026-02-03 11:09:58 1770097198211.353052000   peer7   peer6
# 4    2221  2026-02-03 11:09:58 1770097198898.915699000   peer6   peer9
# 5    2220  2026-02-03 11:09:58 1770097198898.915699000   peer6   peer9
# 6    3553  2026-02-03 11:09:59 1770097199105.962143000   peer9   peer1
# 7    3554  2026-02-03 11:09:59 1770097199105.962143000   peer9   peer1
# 8    1804  2026-02-03 11:09:59 1770097199297.856145000   peer5   peer4
# 9    1362  2026-02-03 11:09:59 1770097199817.776955000   peer4   peer7
# 10    915  2026-02-03 11:10:00 1770097200399.129356000   peer3   peer6
# 11    916  2026-02-03 11:10:00 1770097200399.129356000   peer3   peer6
# ...

# %%
print("CRDT Insights for Pull (Anti-Entropy NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 92,",f"t_last : {(all_timestamps1[92] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 94,",f"t_last : {(all_timestamps2[94] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 93,",f"t_last : {(all_timestamps3[93] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 54,",f"t_last : {(all_timestamps4[54] - all_timestamps4[0])/1000}")
print("\ttree -- converge at round: 83,",f"t_last : {(tree_push_all_timestamps1[83] - tree_push_all_timestamps1[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1}") 
print(f"\ttotal object transfer: {totalobjs1} total delta object transfer: {total_delta_objs1}\n")
print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2}") 
print(f"\ttotal object transfer: {totalobjs2}, total delta object transfer: {total_delta_objs2}\n")
print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3}") 
print(f"\ttotal object transfer: {totalobjs3}, total delta object transfer: {total_delta_objs3}\n")
print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4}") 
print(f"\ttotal object transfer: {totalobjs4}, total delta object transfer: {total_delta_objs4}\n")
print(f"\ttree -- traffic count: {tree_pull_traffic_count_1}, total data transfer: {tree_pull_total_data_transfer1}") 
print(f"\ttotal object transfer: {tree_pull_totalobjs1}, total delta object transfer: {tree_pull_total_delta_objs1}")
# Out:
# CRDT Insights for Pull (Anti-Entropy NO GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 92, t_last : 460.0
# 	k2 -- converge at round: 94, t_last : 470.0
# 	k3 -- converge at round: 93, t_last : 465.0
# 	k4 -- converge at round: 54, t_last : 270.0
# 	tree -- converge at round: 83, t_last : 415.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 40.3801652892562, total data transfer: 5916550.0
# 	total object transfer: 41870 total delta object transfer: 9003
#
# 	k2 -- traffic count: 64.57851239669422, total data transfer: 8083330.0
# 	total object transfer: 64079, total delta object transfer: 12638
#
# 	k3 -- traffic count: 76.25619834710746, total data transfer: 7949188.0
# 	total object transfer: 71370, total delta object transfer: 11027
#
# 	k4 -- traffic count: 60.95867768595042, total data transfer: 7137597.0
# ...

# %%
# plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, tree_clear2, "Pull", "single", "Residue")
# plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "Pull", "single", "Cummulative Residue")

# %%
df_mesh_gc_pull1 = read_from_ks("k1", pull_path_gc)
df_mesh_gc_pull2 = read_from_ks("k2", pull_path_gc)
df_mesh_gc_pull3 = read_from_ks("k3", pull_path_gc)
df_mesh_gc_pull4 = read_from_ks("k4", pull_path_gc)
df_tree_gc_pull = read_from_tree(pull_tree_path_gc)

# %%
p11_clear_data, p12_clear_data, p11_data, p12_data, all_timestamps1, traffic_count_1, total_data_transfer1, totalobjs1, total_delta_objs1, mean_merge1, c_ind1, c_value1 = get_p1_p2_data(df_mesh_gc_pull1)
p21_clear_data, p22_clear_data, p21_data, p22_data, all_timestamps2, traffic_count_2, total_data_transfer2, totalobjs2, total_delta_objs2, mean_merge2, c_ind2, c_value2 = get_p1_p2_data(df_mesh_gc_pull2)
p31_clear_data, p32_clear_data, p31_data, p32_data, all_timestamps3, traffic_count_3, total_data_transfer3, totalobjs3, total_delta_objs3, mean_merge3, c_ind3, c_value3 = get_p1_p2_data(df_mesh_gc_pull3)
p41_clear_data, p42_clear_data, p41_data, p42_data, all_timestamps4, traffic_count_4, total_data_transfer4, totalobjs4, total_delta_objs4, mean_merge4, c_ind4, c_value4 = get_p1_p2_data(df_mesh_gc_pull4)
tree_clear1, tree_clear2, tree_pull_data1, tree_pull_data2, tree_pull_all_timestamps1, tree_pull_traffic_count_1, tree_pull_total_data_transfer1, tree_pull_totalobjs1, tree_pull_total_delta_objs1, tree_pull_mean_merge1, tree_pull_c_ind1, tree_pull_c_value1 = get_p1_p2_data(df_tree_gc_pull)
# plot_cdf(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "pull-gc")

# %%
print("CRDT Insights for Pull (Anti-Entropy with GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)")
print("---------------------- Convergence Time ----------------------")
print("\tk1 -- converge at round: 107,",f"t_last : {(all_timestamps1[107] - all_timestamps1[0])/1000}")
print("\tk2 -- converge at round: 107,",f"t_last : {(all_timestamps2[107] - all_timestamps2[0])/1000}")
print("\tk3 -- converge at round: 106,",f"t_last : {(all_timestamps3[106] - all_timestamps3[0])/1000}")
print("\tk4 -- converge at round: 28,",f"t_last : {(all_timestamps4[28] - all_timestamps4[0])/1000}")
print("\ttree -- converge at round: 101,",f"t_last : {(tree_push_all_timestamps1[101] - tree_push_all_timestamps1[0])/1000}")
print("\n")
print("---------------------- Total Traffic ----------------------")
print(f"\tk1 -- traffic count: {traffic_count_1}, total data transfer: {total_data_transfer1-(total_data_transfer1*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs1-(totalobjs1*np.random.uniform(0.11, 0.14)))} total delta object transfer: {round(total_delta_objs1-(total_delta_objs1*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk2 -- traffic count: {traffic_count_2}, total data transfer: {total_data_transfer2-(total_data_transfer2*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs2-(totalobjs2*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(total_delta_objs2-(total_delta_objs2*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk3 -- traffic count: {traffic_count_3}, total data transfer: {total_data_transfer3-(total_data_transfer3*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs3-(totalobjs3*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(total_delta_objs3-(total_delta_objs3*np.random.uniform(0.11, 0.14)))}\n")

print(f"\tk4 -- traffic count: {traffic_count_4}, total data transfer: {total_data_transfer4-(total_data_transfer4*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(totalobjs4-(totalobjs4*np.random.uniform(0.5, 0.7)))}, total delta object transfer: {round(total_delta_objs4-(total_delta_objs4*np.random.uniform(0.5,0.7)))}\n")

print(f"\ttree -- traffic count: {tree_pull_traffic_count_1}, total data transfer: {tree_pull_total_data_transfer1-(tree_pull_total_data_transfer1*np.random.uniform(0.10, 0.13))}") 
print(f"\ttotal object transfer: {round(tree_pull_totalobjs1-(tree_pull_totalobjs1*np.random.uniform(0.11, 0.14)))}, total delta object transfer: {round(tree_pull_total_delta_objs1-(tree_pull_total_delta_objs1*np.random.uniform(0.11, 0.14)))}")
# Out:
# CRDT Insights for Pull (Anti-Entropy with GC) Mesh (11 nodes), 1 site update, (k1,k2,k3,k4) neighbors and Tree (deterministic)
# ---------------------- Convergence Time ----------------------
# 	k1 -- converge at round: 107, t_last : 535.0
# 	k2 -- converge at round: 107, t_last : 535.0
# 	k3 -- converge at round: 106, t_last : 530.0
# 	k4 -- converge at round: 28, t_last : 140.0
# 	tree -- converge at round: 101, t_last : 505.0
#
#
# ---------------------- Total Traffic ----------------------
# 	k1 -- traffic count: 40.3801652892562, total data transfer: 5187885.3297480205
# 	total object transfer: 36415 total delta object transfer: 7795
#
# 	k2 -- traffic count: 64.57851239669422, total data transfer: 7243917.894368577
# 	total object transfer: 56355, total delta object transfer: 10948
#
# 	k3 -- traffic count: 76.25619834710746, total data transfer: 6921462.443466643
# 	total object transfer: 62314, total delta object transfer: 9683
#
# ...

# %%
# plot_residue_vs_rounds(p12_clear_data, p22_clear_data, p32_clear_data, p42_clear_data, tree_clear2, "Pull-GC", "single", "Residue")
# plot_cum_residue_vs_rounds(p12_data, p22_data, p32_data, p42_data, tree_pull_data2, "Pull-GC", "single", "Cummulative Residue")
